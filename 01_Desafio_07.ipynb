# %% [markdown]
# <a href="https://colab.research.google.com/github/Bertoncini/AluraQuarentenaDados/blob/master/01_Desafio_07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Desafio 07
# Plotar o gráfico de aparições de cada genero, Pode ser um gráfico de tipo igual barra

# %%
import pandas as pd

# %% [markdown]
# importando dados para realização da analise

# %%
filmes = pd.read_csv('https://raw.githubusercontent.com/Bertoncini/AluraQuarentenaDados/master/DataSet/MovieLens/movies.csv')

# %% [markdown]
# Renomeando nomes das colunas

# %%
filmes.columns = ['filmeId','titulo','genero']

# %% [markdown]
# Gerando uma lista dos generos do filmes

# %%
generos_filmes_desagrupado = filmes['genero'].str.split('|')

# %% [markdown]
# Separando os generos, deixando eles em um mesmo array

# %%
generos = []
for row in avalicao_media_filmes:
    for elem in row:
       generos.append(elem)

# %% [markdown]
# Transformando array em Series

# %%
genero_series = pd.Series(generos)

# %% [markdown]
# Plot generos dos filmes

# %%
genero_series.value_counts().plot(kind='bar', title ="Qtd. Generos",figsize=(15,10), fontsize=12)
